# %% [markdown]
# ## Install scrapy

# %%
# !pip3 install scrapy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 5.9 MB/s eta 0:00:006.1 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 7.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 7.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Starting scrapy project

# %%
# !scrapy startproject vulnerabilities
# Out:
# New Scrapy project 'vulnerabilities', using template directory '/home/itaira/proj_py/py_general_projects/.venv/lib/python3.12/site-packages/scrapy/templates/project', created in:
#     /home/itaira/proj_py/py_general_projects/ScrapyUses/vulnerabilities
#
# You can start your first spider with:
#     cd vulnerabilities
#     scrapy genspider example example.com

# %% [markdown]
# ## Defining a spider called cve

# %% [markdown]
# ### A spider in Scrapy is a class that defines how to crawl a website and extract specific data. It specifies the starting URLs, allowed domains, and how to parse the content of the pages to gather information. Spiders are the core of web scraping in Scrapy, automating the process of navigating and extracting data from web pages.

# %%
# !scrapy genspider cve cve.mitre.org
# Out:
# Created spider 'cve' using template 'basic'

# %% [markdown]
# ## Defining scrapy shell

# %%
# In the VSCode shell open one scraoy shell:
scrapy shell https://cve.mitre.org/data/refs/refmap/source-EXPLOIT-DB.html
# Out:
#   Cell In[5], line 1
#     In the VSCode shell open one scraoy shell:scrapy shell https://cve.mitre.org/data/refs/refmap/source-EXPLOIT-DB.html
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Typing response you get the html response for the url
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### using the xpath to search tables
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Finding the interesting table, for as is the bigger table
# ![image.png](attachment:image.png)

# %%
len(response.xpath('//table')[3].xpath('tr'))

# %% [markdown]
# ### Getting the table

# %%
len(response.xpath('//table')[3].xpath('tr'))

# %% [markdown]
# ### Getting the table rows

# %% [markdown]
# #### Child variable to one row

# %% [markdown]
# child = table.xpath('//tr')[10]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Finding the column in the row

# %% [markdown]
# child = table.xpath('//tr')[10]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### After find the intersting column loop it

# %%
for row in table.xpath('tr'):
    try:
        print(row.xpath('td//text()')[0].extract())
    except IndexError:
        pass
    break

# %% [markdown]
# ![image.png](attachment:image.png)
